# %%
# !pip install keras
# !pip install tensorflow
from keras.models import Sequential
from keras.layers import Dense 
import pandas as pd
import numpy as np
import numpy
# Out:
# Requirement already satisfied: keras in c:\users\mansi\appdata\roaming\python\python36\site-packages (2.4.3)
# Requirement already satisfied: pyyaml in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from keras) (5.4.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from keras) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from keras) (1.5.2)
# Requirement already satisfied: h5py in c:\users\mansi\appdata\roaming\python\python36\site-packages (from keras) (3.1.0)
# Requirement already satisfied: cached-property in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from h5py->keras) (1.5.2)
# Requirement already satisfied: tensorflow in c:\users\mansi\appdata\roaming\python\python36\site-packages (2.5.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: six~=1.15.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\mansi\appdata\roaming\python\python36\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast==0.4.0 in c:\users\mansi\appdata\roaming\python\python36\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\mansi\appdata\roaming\python\python36\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\mansi\appdata\roaming\python\python36\site-packages (from tensorflow) (2.5.0.dev2021032900)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\mansi\appdata\roaming\python\python36\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\mansi\appdata\roaming\python\python36\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (0.13.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: cached-property in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.5->tensorflow) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.5->tensorflow) (57.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.5->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.32.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.5->tensorflow) (3.3.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow) (4.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (3.1.1)
# Requirement already satisfied: dataclasses in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from werkzeug>=0.11.15->tensorboard~=2.5->tensorflow) (0.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\mansi\anaconda3\envs\project\lib\site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow) (3.4.1)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-a46f2831a647> in <module>
#       1 get_ipython().system('pip install keras')
#       2 get_ipython().system('pip install tensorflow')
# ----> 3 from keras.models import Sequential
#       4 from keras.layers import Dense
#       5 import pandas as pd
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\__init__.py in <module>
#      18 from . import callbacks
#      19 from . import constraints
# ---> 20 from . import initializers
#      21 from . import metrics
#      22 from . import models
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\initializers\__init__.py in <module>
#     122 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
#     123 # using their correct version.
# --> 124 populate_deserializable_objects()
#     125 globals().update(LOCAL.ALL_OBJECTS)
#     126
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\initializers\__init__.py in populate_deserializable_objects()
#      80     v2_objs = {}
#      81     base_cls = initializers_v2.Initializer
# ---> 82     generic_utils.populate_dict_with_module_objects(
#      83         v2_objs,
#      84         [initializers_v2],
#
# AttributeError: module 'keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'

# %%
import pandas as pd
df = pd.read_csv('diabetes.csv',header = None)

df.head()
# Out:
#              0        1              2              3        4     5  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                           6    7        8
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %%
import numpy as np

# %%
#df.head()
#df[0] = pd.to_numeric(df[0])

df = df.drop(0,axis = 0)

# %%
df[0] = pd.to_numeric(df[0])
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 1  6  148  72  35    0  33.6  0.627  50  1
# 2  1   85  66  29    0  26.6  0.351  31  0
# 3  8  183  64   0    0  23.3  0.672  32  1
# 4  1   89  66  23   94  28.1  0.167  21  0
# 5  0  137  40  35  168  43.1  2.288  33  1

# %%
#choosing X and Y

X = df.drop(8,axis = 1)

y = df[8]

# %%
#scaling the data
from sklearn.preprocessing import scale

X = scale(X)

# %%
#splitting data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#one hot encoding
from tensorflow.python.keras.utils import np_utils
y_train = np_utils.to_categorical(y_train)

# %%
#defining and designing neural network model
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
model = Sequential()
model.add(Dense(12, input_dim = 8, activation = 'relu'))
model.add(Dense(8,activation = 'relu'))
model.add(Dense(2,activation = 'sigmoid'))

# %%
#compiling model
model.compile(loss = 'binary_crossentropy',optimizer = 'adam',metrics = ['accuracy'])

# %%
#training model
model.fit(X_train,y_train,epochs = 150, batch_size = 10)
# Out:
# Epoch 1/150
# 52/52 [==============================] - 1s 2ms/step - loss: 0.6555 - accuracy: 0.6595
# Epoch 2/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6144 - accuracy: 0.6693
# Epoch 3/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5824 - accuracy: 0.6868
# Epoch 4/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5584 - accuracy: 0.6965
# Epoch 5/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7043
# Epoch 6/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5246 - accuracy: 0.7121
# Epoch 7/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5134 - accuracy: 0.7160
# Epoch 8/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7257
# Epoch 9/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4959 - accuracy: 0.7471
# Epoch 10/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4883 - accuracy: 0.7588
# Epoch 11/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4814 - accuracy: 0.7646
# Epoch 12/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4737 - accuracy: 0.7743
# Epoch 13/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4672 - accuracy: 0.7763
# Epoch 14/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.7782
# Epoch 15/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4555 - accuracy: 0.7802
# Epoch 16/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.7802
# Epoch 17/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.7782
# Epoch 18/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.7860
# Epoch 19/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.7938
# Epoch 20/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4358 - accuracy: 0.7938
# Epoch 21/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4331 - accuracy: 0.7977
# Epoch 22/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4315 - accuracy: 0.7957
# Epoch 23/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4284 - accuracy: 0.8016: 0s - loss: 0.4669 - accuracy: 0.
# Epoch 24/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4277 - accuracy: 0.7996
# Epoch 25/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4250 - accuracy: 0.8035
# Epoch 26/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4239 - accuracy: 0.7977
# Epoch 27/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8054
# Epoch 28/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4211 - accuracy: 0.7977
# Epoch 29/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4192 - accuracy: 0.7977
# Epoch 30/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4182 - accuracy: 0.8035
# Epoch 31/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4172 - accuracy: 0.8074
# Epoch 32/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4160 - accuracy: 0.8093
# Epoch 33/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4149 - accuracy: 0.8035
# Epoch 34/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.8054
# Epoch 35/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4126 - accuracy: 0.7996
# Epoch 36/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4125 - accuracy: 0.7938
# Epoch 37/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.4125 - accuracy: 0.8016
# Epoch 38/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4106 - accuracy: 0.8035
# Epoch 39/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.4094 - accuracy: 0.8074
# Epoch 40/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8054
# Epoch 41/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8035
# Epoch 42/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8074
# Epoch 43/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.4062 - accuracy: 0.8035
# Epoch 44/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4050 - accuracy: 0.8054
# Epoch 45/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.4049 - accuracy: 0.8054: 0s - loss: 0.3995 - accuracy: 0.80
# Epoch 46/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8054
# Epoch 47/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8035
# Epoch 48/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.4022 - accuracy: 0.8035
# Epoch 49/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4015 - accuracy: 0.8054
# Epoch 50/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8074
# Epoch 51/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3998 - accuracy: 0.8035
# Epoch 52/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3990 - accuracy: 0.8152
# Epoch 53/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8132
# Epoch 54/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3982 - accuracy: 0.8152
# Epoch 55/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8093
# Epoch 56/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3967 - accuracy: 0.8113
# Epoch 57/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3971 - accuracy: 0.8016
# Epoch 58/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3957 - accuracy: 0.8054
# Epoch 59/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8074
# Epoch 60/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8074
# Epoch 61/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8093
# Epoch 62/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3937 - accuracy: 0.8152
# Epoch 63/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3935 - accuracy: 0.8132
# Epoch 64/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3923 - accuracy: 0.8093
# Epoch 65/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.8171
# Epoch 66/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8152
# Epoch 67/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3905 - accuracy: 0.8113
# Epoch 68/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3904 - accuracy: 0.8171
# Epoch 69/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8171
# Epoch 70/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8152
# Epoch 71/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3881 - accuracy: 0.8191
# Epoch 72/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3875 - accuracy: 0.8191
# Epoch 73/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8132
# Epoch 74/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3863 - accuracy: 0.8191
# Epoch 75/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3857 - accuracy: 0.8171
# Epoch 76/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3846 - accuracy: 0.8210
# Epoch 77/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3848 - accuracy: 0.8191
# Epoch 78/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8191
# Epoch 79/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8230
# Epoch 80/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8307
# Epoch 81/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3822 - accuracy: 0.8249
# Epoch 82/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8210
# Epoch 83/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8210
# Epoch 84/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8230
# Epoch 85/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3803 - accuracy: 0.8327
# Epoch 86/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8268
# Epoch 87/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8249
# Epoch 88/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3775 - accuracy: 0.8307
# Epoch 89/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3778 - accuracy: 0.8268
# Epoch 90/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3770 - accuracy: 0.8288
# Epoch 91/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3759 - accuracy: 0.8288
# Epoch 92/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8307
# Epoch 93/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3758 - accuracy: 0.8288
# Epoch 94/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8327
# Epoch 95/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3733 - accuracy: 0.8307
# Epoch 96/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3731 - accuracy: 0.8346
# Epoch 97/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3731 - accuracy: 0.8288
# Epoch 98/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8307
# Epoch 99/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8307
# Epoch 100/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.8288
# Epoch 101/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.8385
# Epoch 102/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3692 - accuracy: 0.8366
# Epoch 103/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3690 - accuracy: 0.8405
# Epoch 104/150
# 52/52 [==============================] - 0s 1ms/step - loss: 0.3678 - accuracy: 0.8366
# Epoch 105/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3685 - accuracy: 0.8366
# Epoch 106/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.8346
# Epoch 107/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8366
# Epoch 108/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3656 - accuracy: 0.8405
# Epoch 109/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8366
# Epoch 110/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.8327
# Epoch 111/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8424
# Epoch 112/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8405
# Epoch 113/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8327
# Epoch 114/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3615 - accuracy: 0.8385
# Epoch 115/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3610 - accuracy: 0.8424
# Epoch 116/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8346
# Epoch 117/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3588 - accuracy: 0.8385
# Epoch 118/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8405
# Epoch 119/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3586 - accuracy: 0.8385
# Epoch 120/150
# 52/52 [==============================] - 0s 1ms/step - loss: 0.3572 - accuracy: 0.8424
# Epoch 121/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3571 - accuracy: 0.8405
# Epoch 122/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3573 - accuracy: 0.8366
# Epoch 123/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3549 - accuracy: 0.8444
# Epoch 124/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3541 - accuracy: 0.8424
# Epoch 125/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.8385
# Epoch 126/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3530 - accuracy: 0.8424
# Epoch 127/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3521 - accuracy: 0.8385
# Epoch 128/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3515 - accuracy: 0.8444
# Epoch 129/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8366
# Epoch 130/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3496 - accuracy: 0.8405
# Epoch 131/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8405
# Epoch 132/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8405
# Epoch 133/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.8424
# Epoch 134/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.8424
# Epoch 135/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3463 - accuracy: 0.8366
# Epoch 136/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3459 - accuracy: 0.8405
# Epoch 137/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3443 - accuracy: 0.8405
# Epoch 138/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.3443 - accuracy: 0.8463
# Epoch 139/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3429 - accuracy: 0.8424
# Epoch 140/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3425 - accuracy: 0.8482
# Epoch 141/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8444
# Epoch 142/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8463
# Epoch 143/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8444
# Epoch 144/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8405
# Epoch 145/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3399 - accuracy: 0.8424
# Epoch 146/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8385
# Epoch 147/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8444
# Epoch 148/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3377 - accuracy: 0.8385
# Epoch 149/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8385
# Epoch 150/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3358 - accuracy: 0.8385

# %%
#prediction and evaluation
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
y_pred = str(np.argmax(y_pred,axis = 1))
accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d4efed0e1fb8> in <module>
#       3 y_pred = model.predict(X_test)
#       4 y_pred = str(np.argmax(y_pred,axis = 1))
# ----> 5 accuracy_score(y_test,y_pred)
#
# c:\users\mansi\anaconda3\envs\project\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\mansi\anaconda3\envs\project\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     203     check_consistent_length(y_true, y_pred, sample_weight)
#     204     if y_type.startswith('multilabel'):
#
# c:\users\mansi\anaconda3\envs\project\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      81     y_pred : array or indicator matrix
#      82     """
# ---> 83     check_consistent_length(y_true, y_pred)
#      84     type_true = type_of_target(y_true)
#      85     type_pred = type_of_target(y_pred)
#
# c:\users\mansi\anaconda3\envs\project\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     318     if len(uniques) > 1:
#     319         raise ValueError("Found input variables with inconsistent numbers of"
# --> 320                          " samples: %r" % [int(l) for l in lengths])
#     321
#     322
#
# ValueError: Found input variables with inconsistent numbers of samples: [254, 515]

# %%
#plotting loss against no. of epochs 
import matplotlib.pyplot as plt 
plt.plot(model.history.epoch, model.history.history['loss'])
plt.xlabel('epochs')
plt.xlabel('loss')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-b8aae4f2a422> in <module>
#       1 #plotting loss against no. of epochs
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.plot(model.history.epoch, model.history.history['loss'])
#       4 plt.xlabel('epochs')
#       5 plt.xlabel('loss')
#
# AttributeError: 'History' object has no attribute 'epoch'
